# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# Out:
# C:\Users\ankit\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (5.1.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
#Imports the HTML into python
page=requests.get('https://www.makaan.com/bangalore-residential-property/buy-property-in-bangalore-city')
soup = BeautifulSoup(page.text, 'lxml')

# %%
df=pd.DataFrame({"Location":[''],"Society":[''],"type_of_apartment":[''], "Price":[''],"Area":[''],'Status':['']})

# %%
posting=soup.find_all('div',class_="infoWrap")
for post in posting:
    try:
        price=post.find("td",class_="price").text
        area=post.find("td",class_='size').text
        status=post.find("tr",class_="hcol w44").text
        rooms=post.find("a",class_="typelink").text
        location=post.find("a",class_="loclink").text
        society=post.find("a",class_="projName").text
        df=df.append({"Location":location,"Society":society,"type_of_apartment":rooms,"Price":price,"Area":area,'Status':status},ignore_index=True)
    except:
        pass

# %%
for i in range(1,200):
    next_page="https://www.makaan.com/bangalore-residential-property/buy-property-in-bangalore-city?page="+str(i)
    page=requests.get(next_page)
    soup=BeautifulSoup(page.text,"lxml")
    posting=soup.find_all('div',class_="infoWrap")
    for post in posting:
        try:
            price=post.find("td",class_="price").text
            area=post.find("td",class_='size').text
            status=post.find("tr",class_="hcol w44").text
            rooms=post.find("a",class_="typelink").text
            location=post.find("a",class_="loclink").text
            society=post.find("a",class_="projName").text
            df=df.append({"Location":location,"Society":society,"type_of_apartment":rooms,"Price":price,"Area":area,'Status':status},ignore_index=True)
        except:
            pass

# %%
df
# Out:
#                                 Location  \
# 0
# 1             Krishnarajapura, Bangalore
# 2     Electronic City Phase 1, Bangalore
# 3       Karudabande Hosahalli, Bangalore
# 4                    RR Nagar, Bangalore
# ...                                  ...
# 2646              Bommasandra, Bangalore
# 2647  Electronic City Phase 2, Bangalore
# 2648  Electronic City Phase 2, Bangalore
# 2649  Electronic City Phase 2, Bangalore
# 2650  Electronic City Phase 2, Bangalore
#
#                                     Society type_of_apartment     Price  \
# 0
# 1              CasaGrand Casagrand Meridian   3 BHK Apartment   1.18 Cr
# 2                       Shree Nandana Elite   2 BHK Apartment   57.56 L
# 3                    Saroj Whispering Winds  Residential Plot    32.3 L
# 4                          Navami Landmaark   3 BHK Apartment   1.33 Cr
# ...                                     ...               ...       ...
# ...
